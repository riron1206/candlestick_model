# %%
# !pwd
import sys
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
sys.executable
# Out:
# /c/Users/81908/jupyter_notebook/tf_2_work/stock_work/candlestick_model/notebook
# 'C:\\Users\\81908\\Anaconda3\\envs\\tfgpu\\python.exe'

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import os
import glob
import random

random.seed(42)

data_dir = (
    r"D:\work\candlestick_model\output\ts_dataset_all_2day_label_small_class2_reduce"
)

#test_ps = glob.glob(f"{data_dir}/test/2/*png")
#n_del = 900  # 何件消すか
#del_ps = random.sample(test_ps, n_del)  # ランダムサンプリング
#for p in del_ps:
#    os.remove(p)
    
#train_ps = glob.glob(f"{data_dir}/train/2/*png")
#n_del = 900  # 何件消すか
#del_ps = random.sample(train_ps, n_del)  # ランダムサンプリング
#for p in del_ps:
#    os.remove(p)

# %%
import sys
sys.path.append(r'C:\Users\81908\jupyter_notebook\tfgpu_py36_work\02_keras_py\model')
import tf_define_model
from tensorflow import keras

model = tf_define_model.load_model_file(r"D:\work\candlestick_model\output\model\ts_dataset_all_2day_label\Xception\best_val_loss.h5")

tf_define_model.print_model_summary(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 80, 80, 3)]  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 39, 39, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 39, 39, 32)   128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (Activation)   (None, 39, 39, 32)   0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
import yaml
config = yaml.load(r"tmp.yml")
args = {'config': config}
with open(args["config"]) as f:
    config = yaml.load(f)
    args.update(config)
print(args)
